# %% [markdown]
# ## Minimum, Maximum , median , Q1, Q3 , IQR

# %%
import numpy as np

# %%
lst_marks = [45, 32, 56, 89, 54, 32, 89, 90, 100, 23, 67, 45, 78, 88, 92, 11, 39, 47, 53, 60]
minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.5, 0.75, 1])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(11.0),
#  np.float64(43.5),
#  np.float64(55.0),
#  np.float64(88.25),
#  np.float64(100.0))

# %%
IQR = Q3 - Q1
print("Inter Quartile Range (IQR):", IQR)
# Out:
# Inter Quartile Range (IQR): 44.75

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: -23.625
# Upper Bound: 155.375

# %%
lst_marks = [45, 32, 56, 89, 54, 32, 89, 90, 100, 23, 67, 45, 78, 88, 92, 11, 39, 47, 53, 60]

# %%
import seaborn as sns

# %%
sns.boxplot(x=lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-100, -200 ,45, 32, 56, 89, 54, 32, 89, 90, 100, 23, 67, 45, 78, 88, 92, 11, 39, 47, 53, 60, 150, 180, 170]

# %%
sns.boxplot(x=lst_marks)
# Out:
# <Axes: >
