# %% [markdown]
# # Logging with multiple loggers
#
# You can create multiple loggers in your application to separate logging concerns. Each logger can have its own configuration, handlers, and log levels. Here's an example of how to set up and use multiple loggers:

# %%
import logging
## Create a logger for module1
logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)

## Create a logger for module2
logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
)

# %%
## log messages using different loggers
logger1.debug("This is a debug message from module1")
logger1.info("This is an info message from module1")

logger2.warning("This is a warning message from module2")
logger2.error("This is an error message from module2")
# Out:
# 2025-10-21 19:39:12 - module1 - DEBUG - This is a debug message from module1
# 2025-10-21 19:39:12 - module1 - INFO - This is an info message from module1
# 2025-10-21 19:39:12 - module2 - WARNING - This is a warning message from module2
# 2025-10-21 19:39:12 - module2 - ERROR - This is an error message from module2
