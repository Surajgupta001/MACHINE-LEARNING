# %% [markdown]
# # Introduction to streamlit
#
# Streamlit is an open-source app framework for machine learning and data science projects. It allows you to create and share custom web apps for machine learning and data science with minimal effort.
